# %%
import os, sys
import django
from dateutil import parser

sys.path.append('../..') # add path to project root dir
os.environ["DJANGO_SETTINGS_MODULE"] = "tshilo_dikotla.settings"
import pytz, datetime
TIME_ZONE = 'Africa/Gaborone'
tz = pytz.timezone(TIME_ZONE)
d = datetime.datetime(2019, 5, 13).replace(tzinfo=tz)

# for more sophisticated setups, if you need to change connection settings (e.g. when using django-environ):
#os.environ["DATABASE_URL"] = "postgres://myuser:mypassword@localhost:54324/mydb"

# Connect to Django ORM
django.setup()

# %%
from td_prn.models import MaternalOffStudy
count = 0

for mo in MaternalOffStudy.objects.all():
    mo.save()
    count += 1
print("Done ", count)
# Out:
# Done  125

# %%
from td_maternal.models import SubjectConsent
c  = SubjectConsent.objects.filter(subject_identifier=mo.subject_identifier)[0]

# %%
from td_prn.models import InfantOffStudy
count = 0

for io in InfantOffStudy.objects.all():
    io.save()
    count += 1
print("Done ", count)
# Out:
# Done  36

# %%
from td_maternal.models import MaternalLabourDel
from td_prn.models import MaternalOffStudy
actions = ActionItem.objects.filter(reference_model='td_maternal.maternallabourdel')
missing_mld = []
count = 0
for a in actions:
    try:
        mld = MaternalLabourDel.objects.get(subject_identifier=a.subject_identifier)
    except MaternalLabourDel.DoesNotExist:
        missing_mld.append(a.subject_identifier)
    else:
        print(a.reference_identifier)
        mld.tracking_identifier = a.reference_identifier
        mld.action_identifier = a.action_identifier
        mld.save_base(raw=True)
        count += 1
print("Updated: ", count)
# Out:
# MD99-1907-1918-4328-17C7
# MD99-1907-1918-4258-7272
# MD99-1907-1918-4312-822F
# MD99-1907-1918-4322-88BW
# MD99-1907-1918-4258-96P2
# MD99-1907-1918-4318-37ET
# MD99-1907-1918-4307-19XP
# MD99-1907-1918-4317-79PN
# MD99-1907-1918-4258-83BG
# MD99-1907-1918-4322-64RP
# MD99-1907-1918-4351-43ZN
# MD99-1907-1918-4307-92B8
# MD99-1907-1918-4305-01CU
# MD99-1907-1918-4254-65TK
# MD99-1907-1918-4305-62GM
# MD99-1907-1918-4348-89B9
# MD99-1907-1918-4335-208P
# MD99-1907-1918-4334-962H
# MD99-1907-1918-4327-807D
# MD99-1907-1918-4311-34FY
# MD99-1907-1918-4259-63XR
# MD99-1907-1918-4304-26EZ
# MD99-1907-1918-4351-9138
# MD99-1907-1918-4303-022D
# MD99-1907-1918-4322-52KA
# MD99-1907-1918-4346-82MH
# MD99-1907-1918-4305-85VV
# MD99-1907-1918-4327-54YC
# MD99-1907-1918-4350-03UZ
# MD99-1907-1918-4306-93G8
# MD99-1907-1918-4339-89XE
# MD99-1907-1918-4319-45Y2
# MD99-1907-1918-4342-62Z7
# MD99-1907-1918-4303-88W6
# MD99-1907-1918-4319-31TP
# MD99-1907-1918-4324-81CC
# MD99-1907-1918-4302-063P
# ...

# %%
a.__dict__
# Out:
# {'_state': <django.db.models.base.ModelState at 0x12510bf60>,
#  'created': datetime.datetime(2019, 7, 19, 13, 1, 52, 215557, tzinfo=<UTC>),
#  'modified': datetime.datetime(2019, 7, 19, 16, 33, 16, 982679, tzinfo=<UTC>),
#  'user_created': 'coulsonkgathi',
#  'user_modified': 'coulsonkgathi',
#  'hostname_created': 'ckgathi',
#  'hostname_modified': 'ckgathi',
#  'revision': '',
#  'device_created': '99',
#  'device_modified': '99',
#  'id': UUID('db4f1610-f077-4dba-ba94-928e7cd498aa'),
#  'site_id': 40,
#  'subject_identifier': '085-40990009-6',
#  'action_identifier': 'AC99-1907-1915-0152-09B3',
#  'report_datetime': datetime.datetime(2019, 7, 19, 13, 1, 52, 96692, tzinfo=<UTC>),
#  'action_type_id': UUID('48bf035c-4ef4-420d-951a-79d4b358cd1b'),
#  'reference_model': 'td_maternal.maternallabourdel',
#  'reference_identifier': None,
#  'related_reference_model': None,
#  'related_reference_identifier': None,
#  'parent_reference_model': None,
# ...

# %%
import datetime
from django.conf import settings
from django.utils.timezone import make_aware
d.tzinfo
settings.TIME_ZONE
d = make_aware(d)
